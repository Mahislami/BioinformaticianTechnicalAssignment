# %%
def getProteinwithCellularProcess(cellularProcess):
    import requests
    session = requests.Session()
    params = {'process':str(cellularProcess)}
    r = session.get('http://127.0.0.1:8000/process',params=params)
    return (r.json()['body'])

# %%
#getProteinwithCellularProcess(cellularProcess='cell adhesion')

# %%
def getProteinInfo(proteinID):
    import requests
    session = requests.Session()
    params = {'proteinID':proteinID}
    r = session.get('http://127.0.0.1:8000/info',params=params)
    return (r.json()['body'])

# %% [markdown]
# # Command

# %%
getProteinInfo(proteinID=26)
# Out:
# {'ProteinID': 26, 'Accessoin': 'P26039|TLN1_MOUSE', 'AverageMass': '269819', 'Description': 'Talin-1 OS=Mus musculus GN=Tln1 PE=1 SV=2', 'CellularProcesses': "['cell adhesion', 'cell-substrate junction assembly', 'cortical actin cytoskeleton organization', 'cytoskeletal anchoring at plasma membrane', 'integrin activation', 'integrin-mediated signaling pathway']", 'ProteinFunctions': "['actin filament binding', 'integrin binding', 'LIM domain binding', 'phosphatidylinositol binding', 'phosphatidylserine binding', 'protein-containing complex binding', 'structural constituent of cytoskeleton', 'vinculin binding']", 'ReactomePathways': "['Platelet degranulation', 'Integrin alphaIIb beta3 signaling', 'GRB2:SOS provides linkage to MAPK signaling for Integrins', 'p130Cas linkage to MAPK signaling for integrins', 'SEMA3A-Plexin repulsion signaling by inhibiting Integrin adhesion', 'Smooth Muscle Contraction', 'MAP2K and MAPK activation']"}

# %%
def getProteinAllTimePointAbundance(proteinID):
    import requests
    session = requests.Session()
    params = {'proteinID':proteinID}
    r = session.get('http://127.0.0.1:8000/time-point',params=params)
    return r.json()['body']

# %%
getProteinAllTimePointAbundance(proteinID=133)
# Out:
# {'ProteinID': 133,
#  'ZeroHrProteinAbundance': 2804400000,
#  'HalfHrProteinAbundance': 3765300000,
#  'OneHrProteinAbundance': 3920900000,
#  'TwoHrProteinAbundance': 3209400000,
#  'ThreeHrProteinAbundance': 3883300000,
#  'FourHrProteinAbundance': 4060600000,
#  'FiveHrProteinAbundance': 4555000000,
#  'SixHrProteinAbundance': 39046000000,
#  'NineHrProteinAbundance': 4329200000,
#  'TwelveHrProteinAbundance': 4580600000,
#  'TwentyFourHrProteinAbundance': 3790200000}

# %%
def plotTimePointsOf(proteinID):
    import matplotlib.pyplot as plt
    AllTimePointAbundance = getProteinAllTimePointAbundance(proteinID)

    TIME_POINTS = [0, 0.5, 1, 2, 3, 4, 5, 6, 9, 12, 24]

    fig,ax = plt.subplots(figsize=(24, 5))
    ax.scatter(TIME_POINTS, list(AllTimePointAbundance.values())[1:12])
    ax.plot(TIME_POINTS, list(AllTimePointAbundance.values())[1:12])
    ax.set_xticks(TIME_POINTS)

# %%
plotTimePointsOf(proteinID=26)

# %%
def getProteinSingleTimePointAbundance(proteinID, timePoint):
    import requests
    session = requests.Session()
    params = {'proteinID':proteinID,'timePoint':timePoint}
    r = session.get('http://127.0.0.1:8000/single-field-time-point',params=params)
    return (r.json()['body'])

# %%
getProteinSingleTimePointAbundance(proteinID=26, timePoint=3)
# Out:
# {'ProteinID': 26, 'ThreeHrProteinAbundance': 2485300000}

# %%
def getProteinAllTimePointAbundance(timePoint, thresh):
    import requests
    session = requests.Session()
    params = {'timePoint':timePoint, 'thresh':thresh}
    r = session.get('http://127.0.0.1:8000/list',params=params)
    return r.json()['body']

# %%
getProteinAllTimePointAbundance(12, 1000000000)
# Out:
# [{'ProteinID': 26,
#   'Accessoin': 'P26039|TLN1_MOUSE',
#   'AverageMass': '269819',
#   'Description': 'Talin-1 OS=Mus musculus GN=Tln1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1752600000,
#   'HalfHrProteinAbundance': 2531600000,
#   'OneHrProteinAbundance': 2478000000,
#   'TwoHrProteinAbundance': 2255400000,
#   'ThreeHrProteinAbundance': 2485300000,
#   'FourHrProteinAbundance': 2449800000,
#   'FiveHrProteinAbundance': 2428100000,
#   'SixHrProteinAbundance': 23288000000,
#   'NineHrProteinAbundance': 2512400000,
#   'TwelveHrProteinAbundance': 2631900000,
#   'TwentyFourHrProteinAbundance': 2175000000,
#   'CellularProcesses': "['cell adhesion', 'cell-substrate junction assembly', 'cortical actin cytoskeleton organization', 'cytoskeletal anchoring at plasma membrane', 'integrin activation', 'integrin-mediated signaling pathway']",
#   'ProteinFunctions': "['actin filament binding', 'integrin binding', 'LIM domain binding', 'phosphatidylinositol binding', 'phosphatidylserine binding', 'protein-containing complex binding', 'structural constituent of cytoskeleton', 'vinculin binding']",
#   'ReactomePathways': "['Platelet degranulation', 'Integrin alphaIIb beta3 signaling', 'GRB2:SOS provides linkage to MAPK signaling for Integrins', 'p130Cas linkage to MAPK signaling for integrins', 'SEMA3A-Plexin repulsion signaling by inhibiting Integrin adhesion', 'Smooth Muscle Contraction', 'MAP2K and MAPK activation']"},
#  {'ProteinID': 133,
#   'Accessoin': 'Q8VDD5|MYH9_MOUSE',
#   'AverageMass': '226370',
#   'Description': 'Myosin-9 OS=Mus musculus GN=Myh9 PE=1 SV=4',
#   'ZeroHrProteinAbundance': 2804400000,
#   'HalfHrProteinAbundance': 3765300000,
#   'OneHrProteinAbundance': 3920900000,
#   'TwoHrProteinAbundance': 3209400000,
#   'ThreeHrProteinAbundance': 3883300000,
#   'FourHrProteinAbundance': 4060600000,
#   'FiveHrProteinAbundance': 4555000000,
#   'SixHrProteinAbundance': 39046000000,
#   'NineHrProteinAbundance': 4329200000,
#   'TwelveHrProteinAbundance': 4580600000,
#   'TwentyFourHrProteinAbundance': 3790200000,
#   'CellularProcesses': "['actin cytoskeleton reorganization', 'actin filament-based movement', 'actomyosin structure organization', 'angiogenesis', 'blood vessel endothelial cell migration', 'cell adhesion', 'cell morphogenesis involved in differentiation', 'cell-cell adhesion', 'cytokinetic process', 'establishment of meiotic spindle localization', 'establishment of T cell polarity', 'in utero embryonic development', 'meiotic spindle organization', 'membrane protein ectodomain proteolysis', 'monocyte differentiation', 'myoblast fusion', 'negative regulation of actin filament severing', 'phagocytosis, engulfment', 'platelet formation', 'positive regulation of protein processing in phagocytic vesicle', 'protein transport', 'regulation of cell shape', 'uropod organization']",
#   'ProteinFunctions': "['actin binding', 'actin filament binding', 'actin-dependent ATPase activity', 'ADP binding', 'ATP binding', 'ATPase activity', 'calmodulin binding', 'integrin binding', 'microfilament motor activity', 'protein domain specific binding', 'protein homodimerization activity', 'protein membrane anchor']",
#   'ReactomePathways': "['Regulation of actin dynamics for phagocytic cup formation', 'RHO GTPases activate PAKs']"},
#  {'ProteinID': 165,
#   'Accessoin': 'Q9QXS1|PLEC_MOUSE',
#   'AverageMass': '534193',
#   'Description': 'Plectin OS=Mus musculus GN=Plec PE=1 SV=3',
#   'ZeroHrProteinAbundance': 910860000,
#   'HalfHrProteinAbundance': 1079950000,
#   'OneHrProteinAbundance': 989870000,
#   'TwoHrProteinAbundance': 967770000,
#   'ThreeHrProteinAbundance': 1025600000,
#   'FourHrProteinAbundance': 952200000,
#   'FiveHrProteinAbundance': 914450000,
#   'SixHrProteinAbundance': 10960000000,
#   'NineHrProteinAbundance': 991160000,
#   'TwelveHrProteinAbundance': 1050940000,
#   'TwentyFourHrProteinAbundance': 813800000,
#   'CellularProcesses': "['hemidesmosome assembly', 'intermediate filament cytoskeleton organization', 'response to nutrient', 'wound healing']",
#   'ProteinFunctions': "['actin binding', 'ankyrin binding', 'cytoskeletal protein binding', 'protein N-terminus binding', 'structural constituent of cytoskeleton', 'structural constituent of muscle', 'structural molecule activity']",
#   'ReactomePathways': "['Assembly of collagen fibrils and other multimeric structures', 'Caspase-mediated cleavage of cytoskeletal proteins', 'Type I hemidesmosome assembly']"},
#  {'ProteinID': 184,
#   'Accessoin': 'Q8BTM8|FLNA_MOUSE',
#   'AverageMass': '281219',
#   'Description': 'Filamin-A OS=Mus musculus GN=Flna PE=1 SV=5',
#   'ZeroHrProteinAbundance': 10201000000,
#   'HalfHrProteinAbundance': 12051000000,
#   'OneHrProteinAbundance': 12552000000,
#   'TwoHrProteinAbundance': 10802000000,
#   'ThreeHrProteinAbundance': 11861000000,
#   'FourHrProteinAbundance': 12710000000,
#   'FiveHrProteinAbundance': 12743000000,
#   'SixHrProteinAbundance': 124000000000,
#   'NineHrProteinAbundance': 13421000000,
#   'TwelveHrProteinAbundance': 14146000000,
#   'TwentyFourHrProteinAbundance': 11760000000,
#   'CellularProcesses': "['actin crosslink formation', 'actin cytoskeleton organization', 'actin cytoskeleton reorganization', 'adenylate cyclase-inhibiting dopamine receptor signaling pathway', 'angiogenesis', 'blood vessel remodeling', 'cell-cell junction organization', 'cilium assembly', 'cytoplasmic sequestering of protein', 'early endosome to late endosome transport', 'epithelial to mesenchymal transition', 'establishment of protein localization', 'establishment of Sertoli cell barrier', 'formation of radial glial scaffolds', 'heart morphogenesis', 'mitotic spindle assembly', 'mRNA transcription by RNA polymerase II', 'negative regulation of apoptotic process', 'negative regulation of DNA-binding transcription factor activity', 'negative regulation of neuron projection development', 'negative regulation of protein catabolic process', 'negative regulation of transcription by RNA polymerase I', 'positive regulation of actin filament bundle assembly', 'positive regulation of I-kappaB kinase/NF-kappaB signaling', 'positive regulation of integrin-mediated signaling pathway', 'positive regulation of neural precursor cell proliferation', 'positive regulation of neuron migration', 'positive regulation of potassium ion transmembrane transport', 'positive regulation of protein import into nucleus', 'positive regulation of substrate adhesion-dependent cell spreading', 'protein localization to bicellular tight junction', 'protein localization to cell surface', 'protein localization to plasma membrane', 'protein stabilization', 'receptor clustering', 'regulation of actin filament bundle assembly', 'regulation of cell migration', 'regulation of membrane repolarization during atrial cardiac muscle cell action potential', 'regulation of membrane repolarization during cardiac muscle cell action potential', 'semaphorin-plexin signaling pathway', 'synapse organization', 'wound healing, spreading of cells']",
#   'ProteinFunctions': "['actin binding', 'actin filament binding', 'Fc-gamma receptor I complex binding', 'G protein-coupled receptor binding', 'GTPase binding', 'ion channel binding', 'kinase binding', 'mu-type opioid receptor binding', 'potassium channel regulator activity', 'protein homodimerization activity', 'protein kinase C binding', 'protein-containing complex binding', 'Rac GTPase binding', 'Ral GTPase binding', 'Rho GTPase binding', 'SMAD binding', 'small GTPase binding', 'transcription factor binding']",
#   'ReactomePathways': "['Platelet degranulation', 'GP1b-IX-V activation signalling', 'Cell-extracellular matrix interactions', 'RHO GTPases activate PAKs']"},
#  {'ProteinID': 80,
#   'Accessoin': '#CONTAM#CON_ALBU_BOVIN|',
#   'AverageMass': '69294',
#   'Description': 'sp|#CONTAM#CON_ALBU_BOVIN|',
#   'ZeroHrProteinAbundance': 4024500000,
#   'HalfHrProteinAbundance': 16199000000,
#   'OneHrProteinAbundance': 16846000000,
#   'TwoHrProteinAbundance': 6500000000,
#   'ThreeHrProteinAbundance': 13262000000,
#   'FourHrProteinAbundance': 10074000000,
#   'FiveHrProteinAbundance': 9406000000,
#   'SixHrProteinAbundance': 125000000000,
#   'NineHrProteinAbundance': 10789000000,
#   'TwelveHrProteinAbundance': 10446000000,
#   'TwentyFourHrProteinAbundance': 6272000000,
#   'CellularProcesses': 'nan',
#   'ProteinFunctions': 'nan',
#   'ReactomePathways': 'nan'},
#  {'ProteinID': 1,
#   'Accessoin': 'P20152|VIME_MOUSE',
#   'AverageMass': '53688',
#   'Description': 'Vimentin OS=Mus musculus GN=Vim PE=1 SV=3',
#   'ZeroHrProteinAbundance': 10940500000,
#   'HalfHrProteinAbundance': 13138200000,
#   'OneHrProteinAbundance': 13452600000,
#   'TwoHrProteinAbundance': 10606000000,
#   'ThreeHrProteinAbundance': 11143500000,
#   'FourHrProteinAbundance': 11555100000,
#   'FiveHrProteinAbundance': 12615400000,
#   'SixHrProteinAbundance': 138000000000,
#   'NineHrProteinAbundance': 13669700000,
#   'TwelveHrProteinAbundance': 15041200000,
#   'TwentyFourHrProteinAbundance': 11120500000,
#   'CellularProcesses': "['astrocyte development', 'Bergmann glial cell differentiation', 'cellular response to interferon-gamma', 'cellular response to lipopolysaccharide', 'cellular response to muramyl dipeptide', 'intermediate filament organization', 'intermediate filament-based process', 'lens fiber cell development', 'negative regulation of neuron projection development', 'positive regulation of collagen biosynthetic process', 'positive regulation of gene expression', 'positive regulation of glial cell proliferation', 'positive regulation of translation', 'regulation of axonogenesis', 'regulation of mRNA stability', 'regulation of Schwann cell migration', 'SMAD protein signal transduction']",
#   'ProteinFunctions': "['double-stranded RNA binding', 'identical protein binding', 'keratin filament binding', 'kinase binding', 'protein C-terminus binding', 'protein domain specific binding', 'protein kinase binding', 'protein phosphatase 2A binding', 'scaffold protein binding', 'structural constituent of cytoskeleton', 'structural constituent of eye lens', 'structural molecule activity']",
#   'ReactomePathways': "['Caspase-mediated cleavage of cytoskeletal proteins', 'Striated Muscle Contraction']"},
#  {'ProteinID': 298,
#   'Accessoin': 'Q9JHU4|DYHC1_MOUSE',
#   'AverageMass': '532050',
#   'Description': 'Cytoplasmic dynein 1 heavy chain 1 OS=Mus musculus GN=Dync1h1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1808900000,
#   'HalfHrProteinAbundance': 2296600000,
#   'OneHrProteinAbundance': 2365100000,
#   'TwoHrProteinAbundance': 1907900000,
#   'ThreeHrProteinAbundance': 2125100000,
#   'FourHrProteinAbundance': 2195200000,
#   'FiveHrProteinAbundance': 2034000000,
#   'SixHrProteinAbundance': 23609000000,
#   'NineHrProteinAbundance': 2033100000,
#   'TwelveHrProteinAbundance': 2237800000,
#   'TwentyFourHrProteinAbundance': 1668300000,
#   'CellularProcesses': "['cell division', 'cilium movement', 'cytoplasmic microtubule organization', 'cytoplasmic mRNA processing body assembly', 'establishment of spindle localization', 'microtubule-based movement', 'minus-end-directed vesicle transport along microtubule', 'positive regulation of cold-induced thermogenesis', 'positive regulation of intracellular transport', 'positive regulation of spindle assembly', 'regulation of metaphase plate congression', 'regulation of mitotic spindle organization', 'stress granule assembly']",
#   'ProteinFunctions': "['ATP binding', 'ATP-dependent microtubule motor activity, minus-end-directed', 'dynein intermediate chain binding', 'dynein light chain binding', 'dynein light intermediate chain binding']",
#   'ReactomePathways': "['Amplification of signal from unattached kinetochores via a MAD2 inhibitory signal', 'MHC class II antigen presentation', 'Separation of Sister Chromatids', 'Resolution of Sister Chromatid Cohesion', 'Regulation of PLK1 Activity at G2/M Transition', 'HSP90 chaperone cycle for steroid hormone receptors (SHR)', 'Loss of Nlp from mitotic centrosomes', 'Recruitment of mitotic centrosome proteins and complexes', 'Loss of proteins required for interphase microtubule organization from the centrosome', 'Recruitment of NuMA to mitotic centrosomes', 'Anchoring of the basal body to the plasma membrane', 'RHO GTPases Activate Formins', 'Neutrophil degranulation', 'COPI-mediated anterograde transport', 'COPI-independent Golgi-to-ER retrograde traffic', 'Mitotic Prometaphase', 'AURKA Activation by TPX2']"},
#  {'ProteinID': 2,
#   'Accessoin': 'P17182|ENOA_MOUSE',
#   'AverageMass': '47141',
#   'Description': 'Alpha-enolase OS=Mus musculus GN=Eno1 PE=1 SV=3',
#   'ZeroHrProteinAbundance': 6402200000,
#   'HalfHrProteinAbundance': 7692360000,
#   'OneHrProteinAbundance': 6268950000,
#   'TwoHrProteinAbundance': 5207310000,
#   'ThreeHrProteinAbundance': 7307960000,
#   'FourHrProteinAbundance': 7471640000,
#   'FiveHrProteinAbundance': 8235510000,
#   'SixHrProteinAbundance': 75871800000,
#   'NineHrProteinAbundance': 8510710000,
#   'TwelveHrProteinAbundance': 10032800000,
#   'TwentyFourHrProteinAbundance': 6551280000,
#   'CellularProcesses': "['cellular response to interleukin-7', 'glycolytic process', 'in utero embryonic development', 'positive regulation of binding']",
#   'ProteinFunctions': "['DNA-binding transcription repressor activity, RNA polymerase II-specific', 'enzyme binding', 'GTPase binding', 'heat shock protein binding', 'magnesium ion binding', 'phosphopyruvate hydratase activity', 'protein heterodimerization activity', 'protein homodimerization activity', 'RNA binding', 'RNA polymerase II regulatory region sequence-specific DNA binding']",
#   'ReactomePathways': "['Gluconeogenesis']"},
#  {'ProteinID': 8,
#   'Accessoin': 'P40142|TKT_MOUSE',
#   'AverageMass': '67631',
#   'Description': 'Transketolase OS=Mus musculus GN=Tkt PE=1 SV=1',
#   'ZeroHrProteinAbundance': 6356200000,
#   'HalfHrProteinAbundance': 7378300000,
#   'OneHrProteinAbundance': 7183600000,
#   'TwoHrProteinAbundance': 6495800000,
#   'ThreeHrProteinAbundance': 6728700000,
#   'FourHrProteinAbundance': 7605500000,
#   'FiveHrProteinAbundance': 7281600000,
#   'SixHrProteinAbundance': 79820000000,
#   'NineHrProteinAbundance': 7937600000,
#   'TwelveHrProteinAbundance': 8484600000,
#   'TwentyFourHrProteinAbundance': 6633900000,
#   'CellularProcesses': "['glyceraldehyde-3-phosphate biosynthetic process', 'pentose-phosphate shunt', 'pentose-phosphate shunt, non-oxidative branch', 'regulation of growth', 'ribose phosphate biosynthetic process']",
#   'ProteinFunctions': "['carbohydrate binding', 'cofactor binding', 'magnesium ion binding', 'monosaccharide binding', 'protein homodimerization activity', 'thiamine pyrophosphate binding', 'transketolase activity']",
#   'ReactomePathways': "['Pentose phosphate pathway']"},
#  {'ProteinID': 201,
#   'Accessoin': 'Q99PL5|RRBP1_MOUSE',
#   'AverageMass': '172878',
#   'Description': 'Ribosome-binding protein 1 OS=Mus musculus GN=Rrbp1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1930900000,
#   'HalfHrProteinAbundance': 2764400000,
#   'OneHrProteinAbundance': 2876300000,
#   'TwoHrProteinAbundance': 2103200000,
#   'ThreeHrProteinAbundance': 2526000000,
#   'FourHrProteinAbundance': 2626900000,
#   'FiveHrProteinAbundance': 3082500000,
#   'SixHrProteinAbundance': 27220000000,
#   'NineHrProteinAbundance': 3040900000,
#   'TwelveHrProteinAbundance': 3360500000,
#   'TwentyFourHrProteinAbundance': 2909800000,
#   'CellularProcesses': "['protein transport', 'signal transduction']",
#   'ProteinFunctions': '[]',
#   'ReactomePathways': '[]'},
#  {'ProteinID': 175,
#   'Accessoin': 'Q68FD5|CLH1_MOUSE',
#   'AverageMass': '191555',
#   'Description': 'Clathrin heavy chain 1 OS=Mus musculus GN=Cltc PE=1 SV=3',
#   'ZeroHrProteinAbundance': 3949300000,
#   'HalfHrProteinAbundance': 3954200000,
#   'OneHrProteinAbundance': 4524000000,
#   'TwoHrProteinAbundance': 3953900000,
#   'ThreeHrProteinAbundance': 4178300000,
#   'FourHrProteinAbundance': 4325700000,
#   'FiveHrProteinAbundance': 4681300000,
#   'SixHrProteinAbundance': 48907000000,
#   'NineHrProteinAbundance': 4880000000,
#   'TwelveHrProteinAbundance': 5219200000,
#   'TwentyFourHrProteinAbundance': 4058000000,
#   'CellularProcesses': "['amyloid-beta clearance by transcytosis', 'autophagy', 'cell division', 'clathrin coat assembly', 'clathrin-dependent endocytosis', 'Golgi organization', 'intracellular protein transport', 'mitotic cell cycle', 'mitotic spindle assembly', 'negative regulation of hyaluronan biosynthetic process', 'negative regulation of protein localization to plasma membrane', 'receptor internalization', 'receptor-mediated endocytosis', 'regulation of mitotic spindle organization', 'retrograde transport, endosome to Golgi', 'synaptic vesicle endocytosis', 'transferrin transport']",
#   'ProteinFunctions': "['ankyrin binding', 'clathrin light chain binding', 'disordered domain specific binding', 'double-stranded RNA binding', 'heat shock protein binding', 'low-density lipoprotein particle receptor binding', 'peptide binding', 'protein C-terminus binding', 'protein kinase binding', 'structural molecule activity', 'ubiquitin-specific protease binding']",
#   'ReactomePathways': "['Retrograde neurotrophin signalling', 'Gap junction degradation', 'Formation of annular gap junctions', 'MHC class II antigen presentation', 'Lysosome Vesicle Biogenesis', 'Golgi Associated Vesicle Biogenesis', 'Recycling pathway of L1', 'WNT5A-dependent internalization of FZD4', 'WNT5A-dependent internalization of FZD2, FZD5 and ROR2', 'Cargo recognition for clathrin-mediated endocytosis', 'Clathrin-mediated endocytosis', 'VLDLR internalisation and degradation', 'LDL clearance']"},
#  {'ProteinID': 82,
#   'Accessoin': 'P52480|KPYM_MOUSE',
#   'AverageMass': '57845',
#   'Description': 'Pyruvate kinase PKM OS=Mus musculus GN=Pkm PE=1 SV=4',
#   'ZeroHrProteinAbundance': 3530600000,
#   'HalfHrProteinAbundance': 4093000000,
#   'OneHrProteinAbundance': 3669400000,
#   'TwoHrProteinAbundance': 3453000000,
#   'ThreeHrProteinAbundance': 3602100000,
#   'FourHrProteinAbundance': 3947100000,
#   'FiveHrProteinAbundance': 4145900000,
#   'SixHrProteinAbundance': 41313000000,
#   'NineHrProteinAbundance': 4539400000,
#   'TwelveHrProteinAbundance': 5252700000,
#   'TwentyFourHrProteinAbundance': 3892800000,
#   'CellularProcesses': "['animal organ regeneration', 'ATP biosynthetic process', 'cellular response to insulin stimulus', 'glucose metabolic process', 'glycolytic process', 'liver development', 'positive regulation of sprouting angiogenesis', 'programmed cell death', 'protein homotetramerization', 'pyruvate biosynthetic process', 'skeletal muscle tissue regeneration']",
#   'ProteinFunctions': "['ADP binding', 'ATP binding', 'identical protein binding', 'kinase activity', 'magnesium ion binding', 'potassium ion binding', 'pyruvate kinase activity', 'thyroid hormone binding']",
#   'ReactomePathways': "['Neutrophil degranulation', 'Glycolysis']"},
#  {'ProteinID': 305,
#   'Accessoin': 'Q91ZX7|LRP1_MOUSE',
#   'AverageMass': '504745',
#   'Description': 'Prolow-density lipoprotein receptor-related protein 1 OS=Mus musculus GN=Lrp1 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 968200000,
#   'HalfHrProteinAbundance': 1173600000,
#   'OneHrProteinAbundance': 1275900000,
#   'TwoHrProteinAbundance': 1020100000,
#   'ThreeHrProteinAbundance': 1439800000,
#   'FourHrProteinAbundance': 1162100000,
#   'FiveHrProteinAbundance': 1123400000,
#   'SixHrProteinAbundance': 12250000000,
#   'NineHrProteinAbundance': 998400000,
#   'TwelveHrProteinAbundance': 1115200000,
#   'TwentyFourHrProteinAbundance': 1032000000,
#   'CellularProcesses': "['amyloid-beta clearance', 'amyloid-beta clearance by cellular catabolic process', 'amyloid-beta clearance by transcytosis', 'aorta morphogenesis', 'apoptotic cell clearance', 'astrocyte activation involved in immune response', 'cardiac septum development', 'cell population proliferation', 'cellular lipid catabolic process', 'cellular response to amyloid-beta', 'chemoattraction of axon', 'cholesterol metabolic process', 'coronary vasculature development', 'lysosomal transport', 'negative regulation of apoptotic process', 'negative regulation of cell death', 'negative regulation of cell-substrate adhesion', 'negative regulation of cytosolic calcium ion concentration', 'negative regulation of focal adhesion assembly', 'negative regulation of neuron apoptotic process', 'negative regulation of neuron projection development', 'negative regulation of platelet-derived growth factor receptor-beta signaling pathway', 'negative regulation of smooth muscle cell migration', 'negative regulation of Wnt signaling pathway', 'phagocytosis', 'positive regulation of axon extension', 'positive regulation of axon extension involved in regeneration', 'positive regulation of cell death', 'positive regulation of chemokine (C-C motif) ligand 2 secretion', 'positive regulation of cholesterol efflux', 'positive regulation of cholesterol import', 'positive regulation of collateral sprouting of injured axon', 'positive regulation of cytosolic calcium ion concentration', 'positive regulation of endocytosis', 'positive regulation of ERK1 and ERK2 cascade', 'positive regulation of insulin secretion involved in cellular response to glucose stimulus', 'positive regulation of lipid transport', 'positive regulation of lysosomal protein catabolic process', 'positive regulation of neuron projection development', 'positive regulation of phagocytosis', 'positive regulation of protein binding', 'positive regulation of protein localization to plasma membrane', 'positive regulation of protein transport', 'positive regulation of Schwann cell migration', 'positive regulation of vascular associated smooth muscle cell migration', 'protein kinase C-activating G protein-coupled receptor signaling pathway', 'receptor-mediated endocytosis', 'regulation of actin cytoskeleton organization', 'regulation of cholesterol transport', 'regulation of phospholipase A2 activity']",
#   'ProteinFunctions': "['alpha-2 macroglobulin receptor activity', 'apolipoprotein binding', 'calcium ion binding', 'cargo receptor activity', 'clathrin heavy chain binding', 'coreceptor activity', 'protease binding', 'protein-containing complex binding']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 74,
#   'Accessoin': 'P10107|ANXA1_MOUSE',
#   'AverageMass': '38734',
#   'Description': 'Annexin A1 OS=Mus musculus GN=Anxa1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 9102300000,
#   'HalfHrProteinAbundance': 11697000000,
#   'OneHrProteinAbundance': 12080000000,
#   'TwoHrProteinAbundance': 10364200000,
#   'ThreeHrProteinAbundance': 10801000000,
#   'FourHrProteinAbundance': 12284700000,
#   'FiveHrProteinAbundance': 12130700000,
#   'SixHrProteinAbundance': 114000000000,
#   'NineHrProteinAbundance': 12271000000,
#   'TwelveHrProteinAbundance': 13893000000,
#   'TwentyFourHrProteinAbundance': 12095000000,
#   'CellularProcesses': "['actin cytoskeleton reorganization', 'adaptive immune response', 'alpha-beta T cell differentiation', 'arachidonic acid secretion', 'cell surface receptor signaling pathway', 'cellular response to glucocorticoid stimulus', 'cellular response to hydrogen peroxide', 'cellular response to vascular endothelial growth factor stimulus', 'DNA duplex unwinding', 'endocrine pancreas development', 'estrous cycle', 'G protein-coupled receptor signaling pathway, coupled to cyclic nucleotide second messenger', 'gliogenesis', 'granulocyte chemotaxis', 'hepatocyte differentiation', 'inflammatory response', 'innate immune response', 'insulin secretion', 'keratinocyte differentiation', 'monocyte chemotaxis', 'myoblast migration involved in skeletal muscle regeneration', 'negative regulation of exocytosis', 'negative regulation of interleukin-8 secretion', 'negative regulation of phospholipase A2 activity', 'negative regulation of protein secretion', 'negative regulation of T-helper 2 cell differentiation', 'neutrophil clearance', 'neutrophil homeostasis', 'peptide cross-linking', 'phagocytosis', 'positive regulation of apoptotic process', 'positive regulation of cell migration involved in sprouting angiogenesis', 'positive regulation of G1/S transition of mitotic cell cycle', 'positive regulation of interleukin-2 production', 'positive regulation of neutrophil apoptotic process', 'positive regulation of prostaglandin biosynthetic process', 'positive regulation of T cell proliferation', 'positive regulation of T-helper 1 cell differentiation', 'positive regulation of vesicle fusion', 'positive regulation of wound healing', 'prolactin secretion', 'prostate gland development', 'regulation of cell population proliferation', 'regulation of cell shape', 'regulation of hormone secretion', 'regulation of inflammatory response', 'regulation of interleukin-1 production', 'regulation of leukocyte migration', 'response to drug', 'response to estradiol', 'response to interleukin-1', 'response to peptide hormone', 'response to X-ray', 'signal transduction']",
#   'ProteinFunctions': "['calcium ion binding', 'calcium-dependent phospholipid binding', 'calcium-dependent protein binding', 'DNA/DNA annealing activity', 'double-stranded DNA-dependent ATPase activity', 'phospholipase A2 inhibitor activity', 'phospholipid binding', 'protein binding, bridging', 'protein homodimerization activity', 'single-stranded DNA binding', 'single-stranded RNA binding', 'structural molecule activity']",
#   'ReactomePathways': "['G alpha (q) signalling events', 'G alpha (i) signalling events', 'Formyl peptide receptors bind formyl peptides and many other ligands']"},
#  {'ProteinID': 286,
#   'Accessoin': 'Q9JKF1|IQGA1_MOUSE',
#   'AverageMass': '188741',
#   'Description': 'Ras GTPase-activating-like protein IQGAP1 OS=Mus musculus GN=Iqgap1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 3997000000,
#   'HalfHrProteinAbundance': 4527000000,
#   'OneHrProteinAbundance': 4755000000,
#   'TwoHrProteinAbundance': 3810200000,
#   'ThreeHrProteinAbundance': 4373000000,
#   'FourHrProteinAbundance': 4416000000,
#   'FiveHrProteinAbundance': 4264000000,
#   'SixHrProteinAbundance': 46790000000,
#   'NineHrProteinAbundance': 5038000000,
#   'TwelveHrProteinAbundance': 5491000000,
#   'TwentyFourHrProteinAbundance': 4373000000,
#   'CellularProcesses': "['cell migration', 'cellular response to calcium ion', 'cellular response to epidermal growth factor stimulus', 'cellular response to fibroblast growth factor stimulus', 'cellular response to platelet-derived growth factor stimulus', 'epidermal growth factor receptor signaling pathway', 'fibroblast growth factor receptor signaling pathway', 'glomerular visceral epithelial cell development', 'negative regulation of dephosphorylation', 'neuron projection extension', 'platelet-derived growth factor receptor signaling pathway', 'positive regulation of cellular protein localization', 'positive regulation of dendrite development', 'positive regulation of focal adhesion assembly', 'positive regulation of MAP kinase activity', 'positive regulation of peptidyl-tyrosine autophosphorylation', 'positive regulation of protein kinase activity', 'positive regulation of vascular associated smooth muscle cell migration', 'regulation of cytokine production', 'regulation of GTPase activity', 'regulation of mitotic cell cycle', 'response to angiotensin']",
#   'ProteinFunctions': "['calmodulin binding', 'mitogen-activated protein kinase binding', 'phosphatidylinositol-3,4,5-trisphosphate binding', 'protein domain specific binding', 'protein kinase binding', 'protein phosphatase binding', 'protein serine/threonine kinase activator activity', 'protein-containing complex binding', 'protein-containing complex scaffold activity', 'Rac GTPase binding', 'Rho GTPase binding', 'S100 protein binding', 'small GTPase binding']",
#   'ReactomePathways': "['Nephrin family interactions', 'RHO GTPases activate IQGAPs', 'MAP2K and MAPK activation', 'Neutrophil degranulation']"},
#  {'ProteinID': 138,
#   'Accessoin': 'Q61233|PLSL_MOUSE',
#   'AverageMass': '70149',
#   'Description': 'Plastin-2 OS=Mus musculus GN=Lcp1 PE=1 SV=4',
#   'ZeroHrProteinAbundance': 4647500000,
#   'HalfHrProteinAbundance': 5678600000,
#   'OneHrProteinAbundance': 6514500000,
#   'TwoHrProteinAbundance': 5276800000,
#   'ThreeHrProteinAbundance': 5330800000,
#   'FourHrProteinAbundance': 6089300000,
#   'FiveHrProteinAbundance': 5812400000,
#   'SixHrProteinAbundance': 55717000000,
#   'NineHrProteinAbundance': 6273500000,
#   'TwelveHrProteinAbundance': 7201700000,
#   'TwentyFourHrProteinAbundance': 5170700000,
#   'CellularProcesses': "['actin filament bundle assembly', 'actin filament network formation', 'animal organ regeneration', 'cell migration', 'extracellular matrix disassembly', 'positive regulation of podosome assembly', 'protein kinase A signaling', 'regulation of intracellular protein transport', 'response to wounding', 'T cell activation involved in immune response']",
#   'ProteinFunctions': "['actin filament binding', 'calcium ion binding', 'GTPase binding', 'identical protein binding', 'integrin binding']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 78,
#   'Accessoin': 'P16858|G3P_MOUSE',
#   'AverageMass': '35810',
#   'Description': 'Glyceraldehyde-3-phosphate dehydrogenase OS=Mus musculus GN=Gapdh PE=1 SV=2',
#   'ZeroHrProteinAbundance': 2674470000,
#   'HalfHrProteinAbundance': 2978930000,
#   'OneHrProteinAbundance': 2944950000,
#   'TwoHrProteinAbundance': 2678000000,
#   'ThreeHrProteinAbundance': 3081700000,
#   'FourHrProteinAbundance': 3697855000,
#   'FiveHrProteinAbundance': 2531500000,
#   'SixHrProteinAbundance': 35778500000,
#   'NineHrProteinAbundance': 2584290000,
#   'TwelveHrProteinAbundance': 3895200000,
#   'TwentyFourHrProteinAbundance': 2967150000,
#   'CellularProcesses': "['antimicrobial humoral immune response mediated by antimicrobial peptide', 'apoptotic process', 'cAMP-mediated signaling', 'carbohydrate metabolic process', 'cellular response to interferon-gamma', 'defense response to fungus', 'gluconeogenesis', 'glycolytic process', 'killing by host of symbiont cells', 'killing of cells of other organism', 'microtubule cytoskeleton organization', 'multicellular organism development', 'negative regulation of endopeptidase activity', 'negative regulation of translation', 'negative regulation of vascular associated smooth muscle cell apoptotic process', 'neuron apoptotic process', 'peptidyl-cysteine S-trans-nitrosylation', 'positive regulation by organism of apoptotic process in other organism involved in symbiotic interaction', 'positive regulation of cytokine secretion', 'protein homotetramerization', 'protein stabilization', 'response to ammonium ion']",
#   'ProteinFunctions': "['aspartic-type endopeptidase inhibitor activity', 'disordered domain specific binding', 'enzyme binding', 'glyceraldehyde-3-phosphate dehydrogenase (NAD+) (phosphorylating) activity', 'identical protein binding', 'microtubule binding', 'NAD binding', 'NADP binding', 'peptidyl-cysteine S-nitrosylase activity', 'protein homodimerization activity']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 14,
#   'Accessoin': 'Q91VI7|RINI_MOUSE',
#   'AverageMass': '49817',
#   'Description': 'Ribonuclease inhibitor OS=Mus musculus GN=Rnh1 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 4551500000,
#   'HalfHrProteinAbundance': 5699800000,
#   'OneHrProteinAbundance': 5990500000,
#   'TwoHrProteinAbundance': 5244300000,
#   'ThreeHrProteinAbundance': 5558100000,
#   'FourHrProteinAbundance': 5871400000,
#   'FiveHrProteinAbundance': 5958500000,
#   'SixHrProteinAbundance': 53615000000,
#   'NineHrProteinAbundance': 6086300000,
#   'TwelveHrProteinAbundance': 6574700000,
#   'TwentyFourHrProteinAbundance': 5555400000,
#   'CellularProcesses': "['regulation of angiogenesis']",
#   'ProteinFunctions': "['ribonuclease inhibitor activity']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 304,
#   'Accessoin': 'E9Q555|RN213_MOUSE',
#   'AverageMass': '584791',
#   'Description': 'E3 ubiquitin-protein ligase RNF213 OS=Mus musculus GN=Rnf213 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 901500000,
#   'HalfHrProteinAbundance': 1022500000,
#   'OneHrProteinAbundance': 1121600000,
#   'TwoHrProteinAbundance': 949800000,
#   'ThreeHrProteinAbundance': 1059200000,
#   'FourHrProteinAbundance': 1053500000,
#   'FiveHrProteinAbundance': 1078700000,
#   'SixHrProteinAbundance': 12340000000,
#   'NineHrProteinAbundance': 1168600000,
#   'TwelveHrProteinAbundance': 1142200000,
#   'TwentyFourHrProteinAbundance': 1082500000,
#   'CellularProcesses': "['angiogenesis', 'negative regulation of non-canonical Wnt signaling pathway', 'protein autoubiquitination', 'protein homooligomerization', 'protein ubiquitination', 'sprouting angiogenesis', 'ubiquitin-dependent protein catabolic process']",
#   'ProteinFunctions': "['ATPase activity', 'metal ion binding', 'ubiquitin-protein transferase activity']",
#   'ReactomePathways': "['Antigen processing: Ubiquitination & Proteasome degradation']"},
#  {'ProteinID': 135,
#   'Accessoin': 'P40124|CAP1_MOUSE',
#   'AverageMass': '51565',
#   'Description': 'Adenylyl cyclase-associated protein 1 OS=Mus musculus GN=Cap1 PE=1 SV=4',
#   'ZeroHrProteinAbundance': 6499800000,
#   'HalfHrProteinAbundance': 6376800000,
#   'OneHrProteinAbundance': 7130700000,
#   'TwoHrProteinAbundance': 6369000000,
#   'ThreeHrProteinAbundance': 6920000000,
#   'FourHrProteinAbundance': 6560000000,
#   'FiveHrProteinAbundance': 7695000000,
#   'SixHrProteinAbundance': 71890000000,
#   'NineHrProteinAbundance': 7722000000,
#   'TwelveHrProteinAbundance': 8319000000,
#   'TwentyFourHrProteinAbundance': 6754800000,
#   'CellularProcesses': "['actin cytoskeleton organization', 'actin polymerization or depolymerization', 'ameboidal-type cell migration', 'cell morphogenesis', 'establishment or maintenance of cell polarity', 'receptor-mediated endocytosis']",
#   'ProteinFunctions': "['actin binding', 'adenylate cyclase binding']",
#   'ReactomePathways': "['Neutrophil degranulation']"},
#  {'ProteinID': 79,
#   'Accessoin': 'P05064|ALDOA_MOUSE',
#   'AverageMass': '39356',
#   'Description': 'Fructose-bisphosphate aldolase A OS=Mus musculus GN=Aldoa PE=1 SV=2',
#   'ZeroHrProteinAbundance': 9379500000,
#   'HalfHrProteinAbundance': 9699400000,
#   'OneHrProteinAbundance': 9752670000,
#   'TwoHrProteinAbundance': 9882800000,
#   'ThreeHrProteinAbundance': 9841800000,
#   'FourHrProteinAbundance': 11543500000,
#   'FiveHrProteinAbundance': 12181740000,
#   'SixHrProteinAbundance': 126000000000,
#   'NineHrProteinAbundance': 13104800000,
#   'TwelveHrProteinAbundance': 13866400000,
#   'TwentyFourHrProteinAbundance': 9657080000,
#   'CellularProcesses': "['ATP biosynthetic process', 'binding of sperm to zona pellucida', 'fructose 1,6-bisphosphate metabolic process', 'fructose metabolic process', 'glycolytic process', 'glycolytic process through fructose-6-phosphate', 'methylglyoxal biosynthetic process', 'muscle cell cellular homeostasis', 'positive regulation of cell migration', 'protein homotetramerization', 'regulation of cell shape', 'striated muscle contraction']",
#   'ProteinFunctions': "['cytoskeletal protein binding', 'fructose binding', 'fructose-bisphosphate aldolase activity', 'identical protein binding', 'protease binding']",
#   'ReactomePathways': "['Platelet degranulation', 'Neutrophil degranulation', 'Gluconeogenesis']"},
#  {'ProteinID': 150,
#   'Accessoin': 'P08113|ENPL_MOUSE',
#   'AverageMass': '92476',
#   'Description': 'Endoplasmin OS=Mus musculus GN=Hsp90b1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1028100000,
#   'HalfHrProteinAbundance': 1394200000,
#   'OneHrProteinAbundance': 1323417000,
#   'TwoHrProteinAbundance': 1174865000,
#   'ThreeHrProteinAbundance': 1227941000,
#   'FourHrProteinAbundance': 1228500000,
#   'FiveHrProteinAbundance': 1025558000,
#   'SixHrProteinAbundance': 11360340000,
#   'NineHrProteinAbundance': 1178946000,
#   'TwelveHrProteinAbundance': 1309407000,
#   'TwentyFourHrProteinAbundance': 1158856000,
#   'CellularProcesses': "['actin rod assembly', 'cellular response to ATP', 'negative regulation of apoptotic process', 'protein folding', 'regulation of phosphoprotein phosphatase activity', 'response to hypoxia', 'retrograde protein transport, ER to cytosol', 'ubiquitin-dependent ERAD pathway']",
#   'ProteinFunctions': "['ATP binding', 'low-density lipoprotein particle receptor binding', 'protein phosphatase binding', 'RNA binding', 'unfolded protein binding']",
#   'ReactomePathways': "['Trafficking and processing of endosomal TLR', 'Scavenging by Class A Receptors', 'Regulation of Insulin-like Growth Factor (IGF) transport and uptake by Insulin-like Growth Factor Binding Proteins (IGFBPs)', 'Interleukin-4 and Interleukin-13 signaling', 'Post-translational protein phosphorylation']"},
#  {'ProteinID': 316,
#   'Accessoin': 'P26041|MOES_MOUSE',
#   'AverageMass': '67767',
#   'Description': 'Moesin OS=Mus musculus GN=Msn PE=1 SV=3',
#   'ZeroHrProteinAbundance': 1086380000,
#   'HalfHrProteinAbundance': 1360725000,
#   'OneHrProteinAbundance': 1163013000,
#   'TwoHrProteinAbundance': 997560000,
#   'ThreeHrProteinAbundance': 1315019000,
#   'FourHrProteinAbundance': 1400550000,
#   'FiveHrProteinAbundance': 1466610000,
#   'SixHrProteinAbundance': 10408000000,
#   'NineHrProteinAbundance': 1332709000,
#   'TwelveHrProteinAbundance': 1640895000,
#   'TwentyFourHrProteinAbundance': 1772421000,
#   'CellularProcesses': "['cellular response to testosterone stimulus', 'establishment of endothelial barrier', 'establishment of epithelial cell apical/basal polarity', 'gland morphogenesis', 'immunological synapse formation', 'membrane to membrane docking', 'positive regulation of cellular protein catabolic process', 'positive regulation of early endosome to late endosome transport', 'positive regulation of gene expression', 'positive regulation of podosome assembly', 'positive regulation of protein localization to early endosome', 'regulation of cell shape', 'regulation of cell size', 'regulation of lymphocyte migration', 'regulation of organelle assembly', 'T cell aggregation', 'T cell migration', 'T cell proliferation']",
#   'ProteinFunctions': "['actin binding', 'cell adhesion molecule binding', 'double-stranded RNA binding', 'enzyme binding', 'protein kinase binding', 'signaling receptor binding']",
#   'ReactomePathways': "['Recycling pathway of L1']"},
#  {'ProteinID': 85,
#   'Accessoin': 'Q01853|TERA_MOUSE',
#   'AverageMass': '89322',
#   'Description': 'Transitional endoplasmic reticulum ATPase OS=Mus musculus GN=Vcp PE=1 SV=4',
#   'ZeroHrProteinAbundance': 3074700000,
#   'HalfHrProteinAbundance': 3878300000,
#   'OneHrProteinAbundance': 3643800000,
#   'TwoHrProteinAbundance': 3132400000,
#   'ThreeHrProteinAbundance': 3619300000,
#   'FourHrProteinAbundance': 3598900000,
#   'FiveHrProteinAbundance': 3909900000,
#   'SixHrProteinAbundance': 36394000000,
#   'NineHrProteinAbundance': 3937400000,
#   'TwelveHrProteinAbundance': 4096100000,
#   'TwentyFourHrProteinAbundance': 3377700000,
#   'CellularProcesses': "['activation of cysteine-type endopeptidase activity involved in apoptotic process', 'aggresome assembly', 'ATP metabolic process', 'autophagosome maturation', 'autophagy', 'cellular response to arsenite ion', 'cellular response to DNA damage stimulus', 'cellular response to heat', 'double-strand break repair', 'endoplasmic reticulum stress-induced pre-emptive quality control', 'endoplasmic reticulum to Golgi vesicle-mediated transport', 'endosome to lysosome transport via multivesicular body sorting pathway', 'ER-associated misfolded protein catabolic process', 'ERAD pathway', 'flavin adenine dinucleotide catabolic process', 'macroautophagy', 'mitotic spindle disassembly', 'NADH metabolic process', 'positive regulation of ATP biosynthetic process', 'positive regulation of canonical Wnt signaling pathway', 'positive regulation of Lys63-specific deubiquitinase activity', 'positive regulation of mitochondrial membrane potential', 'positive regulation of oxidative phosphorylation', 'positive regulation of proteasomal ubiquitin-dependent protein catabolic process', 'positive regulation of protein catabolic process', 'positive regulation of protein complex assembly', 'positive regulation of protein K63-linked deubiquitination', 'proteasomal protein catabolic process', 'proteasome-mediated ubiquitin-dependent protein catabolic process', 'protein hexamerization', 'protein homooligomerization', 'protein N-linked glycosylation via asparagine', 'protein ubiquitination', 'regulation of aerobic respiration', 'regulation of synapse organization', 'retrograde protein transport, ER to cytosol', 'stress granule disassembly', 'translesion synthesis', 'ubiquitin-dependent ERAD pathway', 'ubiquitin-dependent protein catabolic process', 'viral genome replication']",
#   'ProteinFunctions': "['ADP binding', 'ATP binding', 'ATPase activity', 'BAT3 complex binding', 'deubiquitinase activator activity', 'identical protein binding', 'K48-linked polyubiquitin modification-dependent protein binding', 'lipid binding', 'MHC class I protein binding', 'polyubiquitin modification-dependent protein binding', 'protein domain specific binding', 'protein phosphatase binding', 'protein-containing complex binding', 'signaling receptor binding', 'ubiquitin protein ligase binding', 'ubiquitin-like protein ligase binding', 'ubiquitin-specific protease binding']",
#   'ReactomePathways': "['Translesion Synthesis by POLH', 'HSF1 activation', 'ABC-family proteins mediated transport', 'N-glycan trimming in the ER and Calnexin/Calreticulin cycle', 'Hedgehog ligand biogenesis', 'Josephin domain DUBs', 'Ovarian tumor domain proteases', 'Neutrophil degranulation', 'Protein methylation']"},
#  {'ProteinID': 144,
#   'Accessoin': 'P18242|CATD_MOUSE',
#   'AverageMass': '44954',
#   'Description': 'Cathepsin D OS=Mus musculus GN=Ctsd PE=1 SV=1',
#   'ZeroHrProteinAbundance': 18348000000,
#   'HalfHrProteinAbundance': 20178000000,
#   'OneHrProteinAbundance': 21534000000,
#   'TwoHrProteinAbundance': 19932000000,
#   'ThreeHrProteinAbundance': 20003000000,
#   'FourHrProteinAbundance': 21229000000,
#   'FiveHrProteinAbundance': 19680000000,
#   'SixHrProteinAbundance': 235000000000,
#   'NineHrProteinAbundance': 21298000000,
#   'TwelveHrProteinAbundance': 23858000000,
#   'TwentyFourHrProteinAbundance': 18668000000,
#   'CellularProcesses': "['autophagosome assembly', 'protein catabolic process', 'proteolysis']",
#   'ProteinFunctions': "['aspartic-type endopeptidase activity', 'endopeptidase activity', 'hydrolase activity', 'peptidase activity', 'peptide binding']",
#   'ReactomePathways': "['Collagen degradation', 'Metabolism of Angiotensinogen to Angiotensins', 'MHC class II antigen presentation', 'Neutrophil degranulation']"},
#  {'ProteinID': 142,
#   'Accessoin': 'O88342|WDR1_MOUSE',
#   'AverageMass': '66407',
#   'Description': 'WD repeat-containing protein 1 OS=Mus musculus GN=Wdr1 PE=1 SV=3',
#   'ZeroHrProteinAbundance': 5220400000,
#   'HalfHrProteinAbundance': 5475000000,
#   'OneHrProteinAbundance': 5828000000,
#   'TwoHrProteinAbundance': 5516000000,
#   'ThreeHrProteinAbundance': 5704400000,
#   'FourHrProteinAbundance': 6385100000,
#   'FiveHrProteinAbundance': 6210000000,
#   'SixHrProteinAbundance': 61690000000,
#   'NineHrProteinAbundance': 6725000000,
#   'TwelveHrProteinAbundance': 7199000000,
#   'TwentyFourHrProteinAbundance': 5683800000,
#   'CellularProcesses': "['actin cytoskeleton organization', 'actin filament depolymerization', 'actin filament fragmentation', 'apical junction assembly', 'cortical cytoskeleton organization', 'establishment of planar polarity of follicular epithelium', 'locomotion', 'maintenance of epithelial cell apical/basal polarity', 'neutrophil mediated immunity', 'neutrophil migration', 'platelet formation', 'positive regulation of actin filament depolymerization', 'regulation of actin filament depolymerization', 'regulation of cell shape', 'regulation of oligodendrocyte differentiation', 'regulation of ventricular cardiac muscle cell membrane repolarization', 'sarcomere organization', 'sensory perception of sound']",
#   'ProteinFunctions': "['actin binding', 'actin filament binding']",
#   'ReactomePathways': "['Platelet degranulation']"},
#  {'ProteinID': 1475,
#   'Accessoin': 'P35700|PRDX1_MOUSE',
#   'AverageMass': '22176',
#   'Description': 'Peroxiredoxin-1 OS=Mus musculus GN=Prdx1 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 20574000000,
#   'HalfHrProteinAbundance': 22336000000,
#   'OneHrProteinAbundance': 24313000000,
#   'TwoHrProteinAbundance': 23310000000,
#   'ThreeHrProteinAbundance': 24900000000,
#   'FourHrProteinAbundance': 25891000000,
#   'FiveHrProteinAbundance': 26619000000,
#   'SixHrProteinAbundance': 272000000000,
#   'NineHrProteinAbundance': 28042000000,
#   'TwelveHrProteinAbundance': 30307000000,
#   'TwentyFourHrProteinAbundance': 23761000000,
#   'CellularProcesses': "['cell population proliferation', 'cell redox homeostasis', 'erythrocyte homeostasis', 'hydrogen peroxide catabolic process', 'leukocyte activation', 'natural killer cell activation', 'natural killer cell mediated cytotoxicity', 'regulation of NIK/NF-kappaB signaling', 'regulation of stress-activated MAPK cascade', 'removal of superoxide radicals', 'response to oxidative stress', 'response to reactive oxygen species']",
#   'ProteinFunctions': "['heme binding', 'identical protein binding', 'peroxidase activity', 'peroxiredoxin activity', 'protein homodimerization activity', 'thioredoxin peroxidase activity']",
#   'ReactomePathways': "['Detoxification of Reactive Oxygen Species', 'TP53 Regulates Metabolic Genes']"},
#  {'ProteinID': 69,
#   'Accessoin': 'Q61598|GDIB_MOUSE',
#   'AverageMass': '50537',
#   'Description': 'Rab GDP dissociation inhibitor beta OS=Mus musculus GN=Gdi2 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 1311178000,
#   'HalfHrProteinAbundance': 1502416000,
#   'OneHrProteinAbundance': 1497800000,
#   'TwoHrProteinAbundance': 1359900000,
#   'ThreeHrProteinAbundance': 1301467300,
#   'FourHrProteinAbundance': 1183060000,
#   'FiveHrProteinAbundance': 1156300000,
#   'SixHrProteinAbundance': 16002380000,
#   'NineHrProteinAbundance': 1428446500,
#   'TwelveHrProteinAbundance': 1605820000,
#   'TwentyFourHrProteinAbundance': 1191090000,
#   'CellularProcesses': "['protein transport', 'small GTPase mediated signal transduction', 'vesicle-mediated transport']",
#   'ProteinFunctions': "['GTPase activator activity', 'Rab GDP-dissociation inhibitor activity', 'small GTPase binding']",
#   'ReactomePathways': "['Rho GTPase cycle', 'Neutrophil degranulation', 'RAB GEFs exchange GTP for GDP on RABs']"},
#  {'ProteinID': 1272,
#   'Accessoin': 'P10605|CATB_MOUSE',
#   'AverageMass': '37280',
#   'Description': 'Cathepsin B OS=Mus musculus GN=Ctsb PE=1 SV=2',
#   'ZeroHrProteinAbundance': 8244000000,
#   'HalfHrProteinAbundance': 9436000000,
#   'OneHrProteinAbundance': 9896000000,
#   'TwoHrProteinAbundance': 8785000000,
#   'ThreeHrProteinAbundance': 9193000000,
#   'FourHrProteinAbundance': 9362000000,
#   'FiveHrProteinAbundance': 11716000000,
#   'SixHrProteinAbundance': 115000000000,
#   'NineHrProteinAbundance': 12242000000,
#   'TwelveHrProteinAbundance': 11635000000,
#   'TwentyFourHrProteinAbundance': 9029000000,
#   'CellularProcesses': "['cellular response to thyroid hormone stimulus', 'collagen catabolic process', 'decidualization', 'epithelial cell differentiation', 'negative regulation of cell death', 'proteolysis', 'proteolysis involved in cellular protein catabolic process', 'regulation of catalytic activity', 'viral entry into host cell']",
#   'ProteinFunctions': "['collagen binding', 'cysteine-type endopeptidase activity', 'cysteine-type peptidase activity', 'endopeptidase activity', 'kininogen binding', 'peptidase activity', 'peptide binding', 'protein self-association', 'protein-containing complex binding', 'proteoglycan binding']",
#   'ReactomePathways': "['Collagen degradation', 'Trafficking and processing of endosomal TLR', 'Assembly of collagen fibrils and other multimeric structures', 'MHC class II antigen presentation', 'Neutrophil degranulation']"},
#  {'ProteinID': 99,
#   'Accessoin': 'P99024|TBB5_MOUSE',
#   'AverageMass': '49671',
#   'Description': 'Tubulin beta-5 chain OS=Mus musculus GN=Tubb5 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 2273710000,
#   'HalfHrProteinAbundance': 3159680000,
#   'OneHrProteinAbundance': 3208760000,
#   'TwoHrProteinAbundance': 2585260000,
#   'ThreeHrProteinAbundance': 2775800000,
#   'FourHrProteinAbundance': 3212620000,
#   'FiveHrProteinAbundance': 3570460000,
#   'SixHrProteinAbundance': 26483100000,
#   'NineHrProteinAbundance': 3450500000,
#   'TwelveHrProteinAbundance': 3761800000,
#   'TwentyFourHrProteinAbundance': 3047600000,
# ...
#   'HalfHrProteinAbundance': 1158540000,
#   'OneHrProteinAbundance': 1237720000,
#   'TwoHrProteinAbundance': 841400000,
#   'ThreeHrProteinAbundance': 1038960000,
#   'FourHrProteinAbundance': 1001340000,
#   'FiveHrProteinAbundance': 1079560000,
#   'SixHrProteinAbundance': 10486600000,
#   'NineHrProteinAbundance': 1308350000,
#   'TwelveHrProteinAbundance': 1435540000,
#   'TwentyFourHrProteinAbundance': 1157440000,
#   'CellularProcesses': "['antigen processing and presentation of endogenous peptide antigen via MHC class I', 'antigen processing and presentation of exogenous protein antigen via MHC class Ib, TAP-dependent', 'cellular defense response', 'cellular response to iron ion', 'cellular response to iron(III) ion', 'immune response', 'iron ion homeostasis', 'iron ion transport', 'negative regulation of neuron projection development', 'negative regulation of receptor binding', 'positive regulation of ferrous iron binding', 'positive regulation of protein binding', 'positive regulation of receptor binding', 'positive regulation of receptor-mediated endocytosis', 'positive regulation of T cell cytokine production', 'positive regulation of T cell mediated cytotoxicity', 'positive regulation of transferrin receptor binding', 'protein refolding', 'regulation of erythrocyte differentiation', 'regulation of iron ion transport', 'response to cadmium ion', 'response to drug', 'response to molecule of bacterial origin', 'T cell differentiation in thymus']",
#   'ProteinFunctions': "['identical protein binding']",
#   'ReactomePathways': "['ER-Phagosome pathway', 'Endosomal/Vacuolar pathway', 'Immunoregulatory interactions between a Lymphoid and a non-Lymphoid cell', 'DAP12 interactions', 'DAP12 signaling', 'Neutrophil degranulation', 'Antigen Presentation: Folding, assembly and peptide loading of class I MHC']"},
#  {'ProteinID': 7737,
#   'Accessoin': 'O88668|CREG1_MOUSE',
#   'AverageMass': '24452',
#   'Description': 'Protein CREG1 OS=Mus musculus GN=Creg1 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 1139197000,
#   'HalfHrProteinAbundance': 1300307000,
#   'OneHrProteinAbundance': 1286679000,
#   'TwoHrProteinAbundance': 1154365000,
#   'ThreeHrProteinAbundance': 1192373000,
#   'FourHrProteinAbundance': 1374819000,
#   'FiveHrProteinAbundance': 1152820000,
#   'SixHrProteinAbundance': 15012080000,
#   'NineHrProteinAbundance': 1280370000,
#   'TwelveHrProteinAbundance': 1288520000,
#   'TwentyFourHrProteinAbundance': 1078873000,
#   'CellularProcesses': "['regulation of growth', 'regulation of transcription, DNA-templated']",
#   'ProteinFunctions': "['cofactor binding', 'transcription factor binding']",
#   'ReactomePathways': "['Neutrophil degranulation']"},
#  {'ProteinID': 8252,
#   'Accessoin': 'P84104|SRSF3_MOUSE',
#   'AverageMass': '19330',
#   'Description': 'Serine/arginine-rich splicing factor 3 OS=Mus musculus GN=Srsf3 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 863700000,
#   'HalfHrProteinAbundance': 1091500000,
#   'OneHrProteinAbundance': 1277000000,
#   'TwoHrProteinAbundance': 1067000000,
#   'ThreeHrProteinAbundance': 958474000,
#   'FourHrProteinAbundance': 1167400000,
#   'FiveHrProteinAbundance': 1185000000,
#   'SixHrProteinAbundance': 9992000000,
#   'NineHrProteinAbundance': 1301200000,
#   'TwelveHrProteinAbundance': 1423700000,
#   'TwentyFourHrProteinAbundance': 947500000,
#   'CellularProcesses': "['cellular response to leukemia inhibitory factor', 'insulin receptor signaling pathway', 'mRNA cis splicing, via spliceosome', 'mRNA export from nucleus', 'regulation of alternative mRNA splicing, via spliceosome', 'regulation of mRNA splicing, via spliceosome', 'RNA splicing']",
#   'ProteinFunctions': "['phospholipase binding', 'RNA binding', 'sequence-specific mRNA binding']",
#   'ReactomePathways': '[\'Cleavage of Growing Transcript in the Termination Region\', \'Transport of Mature mRNA derived from an Intron-Containing Transcript\', \'mRNA Splicing - Major Pathway\', "mRNA 3\'-end processing"]'},
#  {'ProteinID': 4785,
#   'Accessoin': 'P47963|RL13_MOUSE',
#   'AverageMass': '24305',
#   'Description': '60S ribosomal protein L13 OS=Mus musculus GN=Rpl13 PE=1 SV=3',
#   'ZeroHrProteinAbundance': 649100000,
#   'HalfHrProteinAbundance': 739800000,
#   'OneHrProteinAbundance': 820700000,
#   'TwoHrProteinAbundance': 673400000,
#   'ThreeHrProteinAbundance': 810600000,
#   'FourHrProteinAbundance': 870900000,
#   'FiveHrProteinAbundance': 868320000,
#   'SixHrProteinAbundance': 7796000000,
#   'NineHrProteinAbundance': 927400000,
#   'TwelveHrProteinAbundance': 1007700000,
#   'TwentyFourHrProteinAbundance': 803390000,
#   'CellularProcesses': "['translation']",
#   'ProteinFunctions': "['structural constituent of ribosome']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 10882,
#   'Accessoin': 'P56391|CX6B1_MOUSE',
#   'AverageMass': '10071',
#   'Description': 'Cytochrome c oxidase subunit 6B1 OS=Mus musculus GN=Cox6b1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1540680000,
#   'HalfHrProteinAbundance': 1938300000,
#   'OneHrProteinAbundance': 2091600000,
#   'TwoHrProteinAbundance': 1856440000,
#   'ThreeHrProteinAbundance': 1835100000,
#   'FourHrProteinAbundance': 1684400000,
#   'FiveHrProteinAbundance': 1686860000,
#   'SixHrProteinAbundance': 20466200000,
#   'NineHrProteinAbundance': 1593500000,
#   'TwelveHrProteinAbundance': 1948400000,
#   'TwentyFourHrProteinAbundance': 1465480000,
#   'CellularProcesses': '[]',
#   'ProteinFunctions': '[]',
#   'ReactomePathways': '[]'},
#  {'ProteinID': 6791,
#   'Accessoin': 'O89023|TPP1_MOUSE',
#   'AverageMass': '61342',
#   'Description': 'Tripeptidyl-peptidase 1 OS=Mus musculus GN=Tpp1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 889480000,
#   'HalfHrProteinAbundance': 1079580000,
#   'OneHrProteinAbundance': 1012800000,
#   'TwoHrProteinAbundance': 944250000,
#   'ThreeHrProteinAbundance': 897480000,
#   'FourHrProteinAbundance': 915950000,
#   'FiveHrProteinAbundance': 1036190000,
#   'SixHrProteinAbundance': 12690800000,
#   'NineHrProteinAbundance': 1186940000,
#   'TwelveHrProteinAbundance': 1158400000,
#   'TwentyFourHrProteinAbundance': 828511000,
#   'CellularProcesses': "['bone resorption', 'central nervous system development', 'epithelial cell differentiation', 'lysosome organization', 'nervous system development', 'neuromuscular process controlling balance', 'peptide catabolic process', 'proteolysis']",
#   'ProteinFunctions': "['endopeptidase activity', 'metal ion binding', 'peptidase activity', 'peptide binding', 'serine-type endopeptidase activity', 'serine-type peptidase activity', 'tripeptidyl-peptidase activity']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 15184,
#   'Accessoin': 'P47955|RLA1_MOUSE',
#   'AverageMass': '11475',
#   'Description': '60S acidic ribosomal protein P1 OS=Mus musculus GN=Rplp1 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 1255250000,
#   'HalfHrProteinAbundance': 1557460000,
#   'OneHrProteinAbundance': 1517378000,
#   'TwoHrProteinAbundance': 1587935000,
#   'ThreeHrProteinAbundance': 1494789000,
#   'FourHrProteinAbundance': 1384887000,
#   'FiveHrProteinAbundance': 1573487800,
#   'SixHrProteinAbundance': 16695430000,
#   'NineHrProteinAbundance': 1651019000,
#   'TwelveHrProteinAbundance': 1748930000,
#   'TwentyFourHrProteinAbundance': 1106183000,
#   'CellularProcesses': "['cytoplasmic translation', 'regulation of translation', 'translational elongation']",
#   'ProteinFunctions': "['protein kinase activator activity', 'ribonucleoprotein complex binding', 'structural constituent of ribosome']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 4995,
#   'Accessoin': 'P62281|RS11_MOUSE',
#   'AverageMass': '18431',
#   'Description': '40S ribosomal protein S11 OS=Mus musculus GN=Rps11 PE=1 SV=3',
#   'ZeroHrProteinAbundance': 784680000,
#   'HalfHrProteinAbundance': 957500000,
#   'OneHrProteinAbundance': 990160000,
#   'TwoHrProteinAbundance': 813740000,
#   'ThreeHrProteinAbundance': 971010000,
#   'FourHrProteinAbundance': 828070000,
#   'FiveHrProteinAbundance': 882900000,
#   'SixHrProteinAbundance': 9514700000,
#   'NineHrProteinAbundance': 1060310000,
#   'TwelveHrProteinAbundance': 1083520000,
#   'TwentyFourHrProteinAbundance': 805850000,
#   'CellularProcesses': "['translation']",
#   'ProteinFunctions': "['rRNA binding', 'structural constituent of ribosome']",
#   'ReactomePathways': "['L13a-mediated translational silencing of Ceruloplasmin expression', 'Major pathway of rRNA processing in the nucleolus and cytosol', 'Translation initiation complex formation', 'Formation of a pool of free 40S subunits', 'Formation of the ternary complex, and subsequently, the 43S complex', 'Ribosomal scanning and start codon recognition']"},
#  {'ProteinID': 7992,
#   'Accessoin': 'P07091|S10A4_MOUSE',
#   'AverageMass': '11721',
#   'Description': 'Protein S100-A4 OS=Mus musculus GN=S100a4 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 2559820000,
#   'HalfHrProteinAbundance': 3461800000,
#   'OneHrProteinAbundance': 3531410000,
#   'TwoHrProteinAbundance': 3294000000,
#   'ThreeHrProteinAbundance': 3388350000,
#   'FourHrProteinAbundance': 3246800000,
#   'FiveHrProteinAbundance': 3473300000,
#   'SixHrProteinAbundance': 38377000000,
#   'NineHrProteinAbundance': 4006600000,
#   'TwelveHrProteinAbundance': 3546900000,
#   'TwentyFourHrProteinAbundance': 3265100000,
#   'CellularProcesses': "['positive regulation of I-kappaB kinase/NF-kappaB signaling']",
#   'ProteinFunctions': "['actin binding', 'calcium ion binding', 'calcium-dependent protein binding', 'identical protein binding', 'RAGE receptor binding', 'transition metal ion binding']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 6695,
#   'Accessoin': 'P62806|H4_MOUSE',
#   'AverageMass': '11367',
#   'Description': 'Histone H4 OS=Mus musculus GN=Hist1h4a PE=1 SV=2',
#   'ZeroHrProteinAbundance': 1051608000,
#   'HalfHrProteinAbundance': 1063760000,
#   'OneHrProteinAbundance': 1056840000,
#   'TwoHrProteinAbundance': 1226640000,
#   'ThreeHrProteinAbundance': 1146330000,
#   'FourHrProteinAbundance': 1322250000,
#   'FiveHrProteinAbundance': 1400960000,
#   'SixHrProteinAbundance': 14412800000,
#   'NineHrProteinAbundance': 1538720000,
#   'TwelveHrProteinAbundance': 1685100000,
#   'TwentyFourHrProteinAbundance': 1230560000,
#   'CellularProcesses': "['DNA replication-dependent nucleosome assembly', 'DNA replication-independent nucleosome assembly', 'DNA-templated transcription, initiation', 'negative regulation of megakaryocyte differentiation', 'nucleosome assembly', 'protein heterotetramerization']",
#   'ProteinFunctions': "['DNA binding', 'protein domain specific binding', 'protein heterodimerization activity']",
#   'ReactomePathways': "['PRC2 methylates histones and DNA', 'Condensation of Prophase Chromosomes', 'Oxidative Stress Induced Senescence', 'Senescence-Associated Secretory Phenotype (SASP)', 'DNA Damage/Telomere Stress Induced Senescence', 'HDACs deacetylate histones', 'PKMTs methylate histone lysines', 'HDMs demethylate histones', 'HATs acetylate histones', 'RMTs methylate histone arginines', 'SIRT1 negatively regulates rRNA expression', 'NoRC negatively regulates rRNA expression', 'SUMOylation of chromatin organization proteins', 'B-WICH complex positively regulates rRNA expression', 'Transcriptional regulation by small RNAs', 'Activated PKN1 stimulates transcription of AR (androgen receptor) regulated genes KLK2 and KLK3', 'Recruitment and ATM-mediated phosphorylation of repair and signaling proteins at DNA double strand breaks', 'Nonhomologous End-Joining (NHEJ)', 'Processing of DNA double-strand break ends', 'G2/M DNA damage checkpoint', 'RNA Polymerase I Promoter Opening', 'RNA Polymerase I Chain Elongation', 'RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function', 'Estrogen-dependent gene expression']"},
#  {'ProteinID': 10674,
#   'Accessoin': 'P63254|CRIP1_MOUSE',
#   'AverageMass': '8550',
#   'Description': 'Cysteine-rich protein 1 OS=Mus musculus GN=Crip1 PE=1 SV=2',
#   'ZeroHrProteinAbundance': 2791468000,
#   'HalfHrProteinAbundance': 3409420000,
#   'OneHrProteinAbundance': 3551300000,
#   'TwoHrProteinAbundance': 3418800000,
#   'ThreeHrProteinAbundance': 3146800000,
#   'FourHrProteinAbundance': 3758800000,
#   'FiveHrProteinAbundance': 4061000000,
#   'SixHrProteinAbundance': 41200000000,
#   'NineHrProteinAbundance': 3813000000,
#   'TwelveHrProteinAbundance': 3917980000,
#   'TwentyFourHrProteinAbundance': 3174100000,
#   'CellularProcesses': "['cellular response to antibiotic', 'cellular response to UV-B', 'intrinsic apoptotic signaling pathway in response to DNA damage', 'response to zinc ion']",
#   'ProteinFunctions': "['AT DNA binding', 'DNA binding, bending', 'peptide binding', 'zinc ion binding']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 8967,
#   'Accessoin': 'P62900|RL31_MOUSE',
#   'AverageMass': '14463',
#   'Description': '60S ribosomal protein L31 OS=Mus musculus GN=Rpl31 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 558300000,
#   'HalfHrProteinAbundance': 1067900000,
#   'OneHrProteinAbundance': 1249400000,
#   'TwoHrProteinAbundance': 816800000,
#   'ThreeHrProteinAbundance': 1019800000,
#   'FourHrProteinAbundance': 917000000,
#   'FiveHrProteinAbundance': 1074400000,
#   'SixHrProteinAbundance': 9169000000,
#   'NineHrProteinAbundance': 1239500000,
#   'TwelveHrProteinAbundance': 1288800000,
#   'TwentyFourHrProteinAbundance': 1161000000,
#   'CellularProcesses': "['cytoplasmic translation']",
#   'ProteinFunctions': "['structural constituent of ribosome']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 8159,
#   'Accessoin': 'P60867|RS20_MOUSE',
#   'AverageMass': '13373',
#   'Description': '40S ribosomal protein S20 OS=Mus musculus GN=Rps20 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 1346710000,
#   'HalfHrProteinAbundance': 1920013000,
#   'OneHrProteinAbundance': 1659577000,
#   'TwoHrProteinAbundance': 1301650000,
#   'ThreeHrProteinAbundance': 1518955000,
#   'FourHrProteinAbundance': 1577800000,
#   'FiveHrProteinAbundance': 1572820000,
#   'SixHrProteinAbundance': 16845700000,
#   'NineHrProteinAbundance': 1728200000,
#   'TwelveHrProteinAbundance': 2250580000,
#   'TwentyFourHrProteinAbundance': 1375120000,
#   'CellularProcesses': "['translation']",
#   'ProteinFunctions': "['RNA binding', 'structural constituent of ribosome']",
#   'ReactomePathways': "['L13a-mediated translational silencing of Ceruloplasmin expression', 'Major pathway of rRNA processing in the nucleolus and cytosol', 'Translation initiation complex formation', 'Formation of a pool of free 40S subunits', 'Formation of the ternary complex, and subsequently, the 43S complex', 'Ribosomal scanning and start codon recognition']"},
#  {'ProteinID': 9449,
#   'Accessoin': 'Q91VW3|SH3L3_MOUSE',
#   'AverageMass': '10477',
#   'Description': 'SH3 domain-binding glutamic acid-rich-like protein 3 OS=Mus musculus GN=Sh3bgrl3 PE=1 SV=1',
#   'ZeroHrProteinAbundance': 1328420000,
#   'HalfHrProteinAbundance': 2229900000,
#   'OneHrProteinAbundance': 2154800000,
#   'TwoHrProteinAbundance': 1309200000,
#   'ThreeHrProteinAbundance': 1976400000,
#   'FourHrProteinAbundance': 2308800000,
#   'FiveHrProteinAbundance': 2402300000,
#   'SixHrProteinAbundance': 13792000000,
#   'NineHrProteinAbundance': 2316300000,
#   'TwelveHrProteinAbundance': 3039800000,
#   'TwentyFourHrProteinAbundance': 2457260000,
#   'CellularProcesses': "['cell redox homeostasis']",
#   'ProteinFunctions': "['electron transfer activity', 'protein disulfide oxidoreductase activity']",
#   'ReactomePathways': '[]'},
#  {'ProteinID': 15815,
#   'Accessoin': 'P62274|RS29_MOUSE',
#   'AverageMass': '6677',
#   'Description': '40S ribosomal protein S29 OS=Mus musculus GN=Rps29 PE=3 SV=2',
#   'ZeroHrProteinAbundance': 1050200000,
#   'HalfHrProteinAbundance': 1153600000,
#   'OneHrProteinAbundance': 972800000,
#   'TwoHrProteinAbundance': 1105420000,
#   'ThreeHrProteinAbundance': 1129900000,
#   'FourHrProteinAbundance': 1319300000,
#   'FiveHrProteinAbundance': 1530000000,
#   'SixHrProteinAbundance': 15150000000,
#   'NineHrProteinAbundance': 1678300000,
#   'TwelveHrProteinAbundance': 1766300000,
#   'TwentyFourHrProteinAbundance': 1280700000,
#   'CellularProcesses': "['cytoplasmic translation', 'positive regulation of apoptotic process', 'translation']",
#   'ProteinFunctions': "['structural constituent of ribosome', 'zinc ion binding']",
#   'ReactomePathways': '[]'}]

# %%
def plotTimePointsOf2(timePoint, thresh):
    import matplotlib.pyplot as plt
    AllTimePointAbundance = getProteinAllTimePointAbundance(timePoint, thresh)

    TIME_POINTS = [0, 0.5, 1, 2, 3, 4, 5, 6, 9, 12, 24]
    
    plt.figure(figsize=(24, 5))
    for item in AllTimePointAbundance:
    
        #fig,ax = plt.subplots(figsize=(24, 5))
        plt.scatter(TIME_POINTS, list(item.values())[4:15])
        plt.plot(TIME_POINTS, list(item.values())[4:15])
        plt.xticks(TIME_POINTS)
    #plt.show()

# %%
plotTimePointsOf2(12, 10000000000)
